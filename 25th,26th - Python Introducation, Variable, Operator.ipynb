# %% [markdown]
# Basic Python Programming

# %%
import sys
sys.version
# Out:
# '3.11.7 | packaged by Anaconda, Inc. | (main, Dec 15 2023, 18:05:47) [MSC v.1916 64 bit (AMD64)]'

# %% [markdown]
# Work With Numbers

# %%
3
# Out:
# 3

# %%
2
# Out:
# 2

# %%
3+2
# Out:
# 5

# %%
3-2
# Out:
# 1

# %%
3*2
# Out:
# 6

# %%
3**2
# Out:
# 9

# %%
3**2
# Out:
# 9

# %%
10/5
# Out:
# 2.0

# %%
10//5
# Out:
# 2

# %%
# wotk with String

# %%
helloworld
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 helloworld
#
# NameError: name 'helloworld' is not defined

# %%
'helloworld'
# Out:
# 'helloworld'

# %%
"helloworld"
# Out:
# 'helloworld'

# %%
'''helloworld'''
# Out:
# 'helloworld'

# %% [markdown]
# Variable = object

# %%
v = 5 # v - variable and 5 for value
v
# Out:
# 5

# %%
type(v)
# Out:
# int

# %%
v1= 'hello'
v1
# Out:
# 'hello'

# %%
v1

# %% [markdown]
# 26 th

# %%
a = 5.5
type(a)
# Out:
# float

# %%
import sys
sys.version
# Out:
# '3.11.7 | packaged by Anaconda, Inc. | (main, Dec 15 2023, 18:05:47) [MSC v.1916 64 bit (AMD64)]'

# %%
nit = 15 # Python is Case-sensitive 
NIT
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[63], line 2
#       1 nit = 15
# ----> 2 NIT
#
# NameError: name 'NIT' is not defined

# %%
nit
# Out:
# 15

# %%
1a = 67 # Rule 2. Python Veriable never starts with integer but ends with integer
1a
# Out:
#   Cell In[67], line 1
#     1a = 67
#     ^
# SyntaxError: invalid decimal literal

# %%
a1 =67 # Veriable ends with integer
a1
# Out:
# 67

# %%
nit$ = 89 #Rule 3. Python Never use special symbol except _(Underscore)
nit$
# Out:
#   Cell In[71], line 1
#     nit$ = 89
#        ^
# SyntaxError: invalid syntax

# %%
x_train, x_test, y_train, y_test = 80, 20, 70, 30 # here if you decare multiple veriable but it takes last one value

# %%
x_train
x_test
y_train
y_test
# Out:
# 30

# %%
print(x_train)
print(x_test)
print(y_train)
print(y_test)
# Out:
# 80
# 20
# 70
# 30

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
if = 90 # never use Predefine keyword
if
# Out:
#   Cell In[112], line 1
#     if = 90
#        ^
# SyntaxError: invalid syntax

# %%
a10 = 78
a9 = 89

# %%
print(a10)
print(a9)
# Out:
# 78
# 89

# %%
del a10 # here if you del funcation then it will delete value from memory. for that reaseon you  get "name 'a10' is not defined" error

# %%
a10
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[122], line 1
# ----> 1 a10
#
# NameError: name 'a10' is not defined

# %%
for = 90
# Out:
#   Cell In[130], line 1
#     for = 90
#         ^
# SyntaxError: invalid syntax

# %%
For = 90
For
# Out:
# 90

# %%
a = True
a
# Out:
# True

# %%
b = 'True'
b
# Out:
# 'True'

# %%
pi = 3.17 # pi value never prefix
pi
# Out:
# 3.17

# %%
pi = 3.20
pi
# Out:
# 3.2

# %%
aaaaaaaaaaaaaaaaaaaaaaaa = 90 #never declare variable such way 
aaaaaaaaaaaaaaaaaaaaaaaa
# Out:
# 90
